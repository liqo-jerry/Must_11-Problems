# %% [markdown]
# ## Problem 10 — Count Vowels, Consonants, Uppercase and Lowercase Characters
#
# ### 📌 Question
#
# Input a string and count:
#
# Vowels
# Consonants
# Uppercase characters
# Lowercase characters
#
# ### 🐍 Python Program

# %%
# Program to count vowels, consonants,
# uppercase and lowercase characters

# Input a string
text = input("Enter a string: ")

# Counters
vowels = 0
consonants = 0
uppercase = 0
lowercase = 0

# Check every character
for ch in text:

    # Check uppercase
    if ch.isupper():
        uppercase = uppercase + 1

    # Check lowercase
    if ch.islower():
        lowercase = lowercase + 1

    # Check whether it is an alphabet
    if ch.isalpha():

        # Check vowel
        if ch.lower() in "aeiou":
            vowels = vowels + 1

        # Otherwise it is a consonant
        else:
            consonants = consonants + 1

# Display results
print("Number of vowels =", vowels)
print("Number of consonants =", consonants)
print("Number of uppercase characters =", uppercase)
print("Number of lowercase characters =", lowercase)
# Out:
# Enter a string:  Liqorious jerry
# Number of vowels = 6
# Number of consonants = 8
# Number of uppercase characters = 1
# Number of lowercase characters = 13
